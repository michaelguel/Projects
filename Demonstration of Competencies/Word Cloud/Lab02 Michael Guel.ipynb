# %% [markdown]
# # Exercise 02: Word Clouding using Basic Data Types
#
# In this exercise you are going to make a Word Cloud: a collage that representes how often a word is used in a body of text by how large the word appears in the image.  With the exception of the code included in this notebook skelenton, you should only need to use the basic Python data types (strings, lists, sets, and dictionaries), if-statements, and for-loops to complete this project.
#
#
# ## Overview
# Input: the text of *Frankenstein*
#
# Final Data Output: A dictionary with the keys being uncommon words from the book paired to the frequency of the word
#
# Final Visual: A word cloud of these uncommon words
#
#
# ## Objectives
# + Learn to install packages using Anaconda Navigator
# + Explore using a Python notebook
# + Demonstrate your undertanding of Python built-in data types: sets, lists, dictionaries, strings
#
#
# ## Before you begin
# Make sure you have installed the wordcloud package from conda-forge.
#
# **Remember to execute the cells in order to run the code in them.  If you want to start over, you can restart the Kernel from the menu**
#
# **Also add cells and explore the output along the way.  Development and analysis is an iterative process.**

# %%
# Here are our package imports
# We'll discuss them later

# Needed for our HTTP requests
import urllib  

# Needed to do the plotting
from matplotlib import pyplot as plt  

# I want to make the figure larger
plt.rcParams['figure.figsize'] = (40,30) 

# Our third-party WordCloud library
from wordcloud import WordCloud

# %% [markdown]
# ## Part 0: Downloading a book
#
# For this exercise we are going to download the book *Frankenstein* by Mary Shelly. The cell below does this for you.  Run this cell to download the book as a single string called `book_text`.

# %%
import urllib
url = 'http://www.cse.msu.edu/~ruppmatt/itm891/frankenstein.txt'
with urllib.request.urlopen(url) as response:
    book_text = response.read().decode('utf-8')  # This is a string that contains the book

# %% [markdown]
# ## Part 1: Preprocessing the text of the book
#
# ### Overview
#
# Input: A string containing the text of the book (you should have executed the code cells above before you execute any cells below)
#
# Output: A string of the text of the book that contains capitalized words and spaces *only*.
#
#
# ### Description
#
# The string `book_text` created in the Part 0 contains numbers, punctuation, and other characters that we don't want to include in our final word cloud.  Before we go any further, let's remove those characters.  While we're at it, let's rid ourselves of lowercase letters so that the words at beginning of sentences and proper nouns aren't counted differently than words that are all lowercase.
#
# Consider the following questions when solving this sub-problem:
# * We want to handle just capital letters.  Is there a way to make a new string that contains an uppercase version of the `book_text` string?  (Use Google!)
#     + Once we've converted the string to uppercase, we will only work with that string from now on, not the original that contained both upper and lowercase letters.
# * How do you know what characters are in the text of the book?
#     + Which data structure deals with keeping a collection of unique objects?
#     + What happens when you create this data structure with a string as the only parameter?  Play with that idea in the notebook.
#     + Create an collection (list, set, dict pick one) that contains the unqiue characters in the capitalized version of the text.
# * If you have a collection of unique characters in the book and a collection of English capitalized letters and space, how would you find the characters you would like to replace?
#     + Look at the documentation for this collection datatype that contains unique elements.  Is there a way to subtract one collection from another?  The result should give you all the characters you need to replace.
# * Once you've gotten a collection of characters you want to remove, how do you remove them?
#     + Try replacing them with spaces.  Is there a method you can call on a string to do this?  (Google it!)
#     + Make a loop that will iterate over the characters you would like to remove and replace them with spaces in the uppercase book string.  This will be the output for this part of the exercise.
#
# To answer the questions above, consider the strengths of the basic data types we covered today and the methods you may call on them.  Google the documentation!

# %%
# Place your solution to the subproblem here

upper_book_text = book_text.upper()
book_characters = set(book_text)
chars_to_keep = set(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'))
replace_book_characters = book_characters - chars_to_keep
for char in replace_book_characters:
    upper_book_text = upper_book_text.replace(char, ' ')

# %% [markdown]
# ## Part 2: Creating collection of unique words in the book
#
# ### Overview
#
# Input: A string containing the capitalized text of the book and whitespace
#
# Output: A collection of unique words in the book
#
#
# ### Description
#
# In the next section we are going to remove common words from the text.  Before we do that, we need to know what words are used in the book.
#
# + We're working on the uppercase string version of the book with non-English and non-space characters removed.
# + Is there some way to split the string into words?  Google it.
# + Once we have a collection of all words in the book, is there a way to convert that to a collection of *unique* words in the book?  What data structure would you use?  What happens if you initialize that data structure with a list of words?

# %%
# Place your solution to the subproblem here
split_words = upper_book_text.split()
my_set = set(split_words)
print(my_set)
# Out:
# {'COMPANION', 'TEASED', 'THROUGHOUT', 'NURSED', 'ERADICATING', 'ENGAGES', 'OPERATION', 'BESIDES', 'NEITHER', 'HIDEOUSLY', 'SAVOURY', 'WEAKENED', 'ROUSES', 'POWER', 'AMPHITHEATRE', 'GEOGRAPHY', 'FINISH', 'INURING', 'INJURER', 'CHEAT', 'APPROACHED', 'ROUGH', 'REMIND', 'ASIDE', 'IRRETRIEVABLE', 'HAST', 'ASSERTION', 'LOOSE', 'KINDLED', 'RELIEVE', 'SOLITUDES', 'PRECIPITATE', 'BLIGHT', 'SOUND', 'THINKS', 'ALOUD', 'POSITIVELY', 'ANIMATION', 'VERGE', 'FOUND', 'DISK', 'OPEN', 'QUICK', 'OPINIONS', 'ACT', 'EMULATE', 'SPARKLED', 'MECHANICS', 'QUANTITY', 'ADMIRE', 'SAT', 'LYCURGUS', 'HELPED', 'IMITATE', 'WOMEN', 'ATTRIBUTED', 'SCENES', 'FRIENDS', 'PREVAIL', 'FEARLESS', 'BAT', 'SUSTAIN', 'BANISHED', 'INDIRECT', 'FALLING', 'INCOMMODED', 'ACTION', 'SPURRED', 'FORBIDDEN', 'UNBRIDLED', 'RULED', 'HEAVING', 'EXTORT', 'MORTIFICATION', 'COVERED', 'WATERFALLS', 'SWORD', 'OCCASIONS', 'RANKLING', 'SCALE', 'COUNTLESS', 'HALF', 'MORNING', 'SIMPLER', 'MORTAL', 'RASH', 'CIVILISED', 'SHOW', 'LEATHERN', 'VARIED', 'WATCHED', 'NOW', 'PLEAD', 'NIECE', 'RECEIPT', 'CONDUCE', 'MUTINY', 'SAILORS', 'AMERICAN', 'INNOCENCE', 'ACTING', 'ENTREATING', 'INTERESTED', 'IMPROVED', 'TOP', 'TIDE', 'CONSISTENT', 'WESTMORLAND', 'SEIZE', 'SWIM', 'LAYING', 'BEGGED', 'DEBTS', 'HELPLESS', 'PAYS', 'MANON', 'SCOTLAND', 'DEPARTMENT', 'CABINETS', 'PILE', 'PULLING', 'HIMSELF', 'WANDERINGS', 'ROMAN', 'COMRADES', 'OTHERWISE', 'CONDUCTING', 'OWE', 'WHALE', 'WEALTH', 'UNFOLDED', 'STORES', 'COME', 'OVERFLOWING', 'AMIDST', 'COMPREHENDED', 'INDEFATIGABLE', 'DOWNCAST', 'SUPERFLUOUS', 'POINT', 'UNEXPECTED', 'SWITZERLAND', 'ENDOW', 'DENIED', 'BREACH', 'KISS', 'PERSECUTED', 'QUIVERED', 'MEASURES', 'WAKEFIELD', 'OVERWHELMED', 'BADE', 'PROPER', 'EARLY', 'SPOTS', 'JOURNEY', 'DESCRIPTION', 'ADDRESSED', 'GRADUALLY', 'PAIL', 'DRAWN', 'NORTHERLY', 'SATAN', 'FASHIONED', 'SINCERITY', 'GOOD', 'AFFABILITY', 'PROPAGATED', 'TEXTURE', 'RESIGNATION', 'LAKE', 'TREES', 'PRAYERS', 'LAMB', 'BOOKS', 'SUSPENSE', 'WORLD', 'BID', 'DEVOLVED', 'OXFORD', 'RISEN', 'PICTURE', 'PORTRAIT', 'ATTRACTIVE', 'PROPERTIES', 'CARRIAGE', 'GLIMMER', 'FEW', 'CONCEALMENT', 'TOWNS', 'ENTICEMENT', 'POSTPONE', 'EXPERIENCED', 'TRICKLE', 'AWARE', 'UNDERGO', 'MALICE', 'EXPLORE', 'PROTECTING', 'KINSMAN', 'CONCEPT', 'BROTHERLY', 'BUILDING', 'DIET', 'UNOBSERVING', 'INDEED', 'PYRAMIDS', 'POET', 'PLUTARCH', 'SADNESS', 'WHENCE', 'APPOINTMENT', 'MURDER', 'RESENTMENT', 'OUTLINES', 'NOISOME', 'BROW', 'POCKET', 'SKILL', 'LOVEDST', 'SHOUT', 'POLE', 'FELL', 'MOMENT', 'CANOPY', 'CONDUCTOR', 'ABOUT', 'ABROAD', 'EXCESSIVE', 'HOMEWARD', 'MACHINE', 'IMPERTINENT', 'IMPERIAL', 'TRAVELS', 'VISIONS', 'PULPIT', 'TROD', 'MUSCLES', 'SUCCEEDED', 'LATE', 'ASSASSINATED', 'UNPLASTERED', 'RESIDED', 'FORCIBLE', 'SWEAR', 'OFFICE', 'MAINZ', 'DISPLAYS', 'STUPENDOUS', 'LURKED', 'ETERNALLY', 'PLAINPALAIS', 'PALPITATE', 'MATLOCK', 'DETAILS', 'MISDEED', 'FEMALE', 'CONDUCTORS', 'SOMBRE', 'CONTRIBUTIONS', 'EXCELLENCE', 'CONSTRUED', 'CONTENT', 'AGED', 'GALLERY', 'PHENOMENA', 'THIRSTED', 'ROLLED', 'CLOSING', 'STAND', 'GALE', 'PEDESTRIAN', 'DEADLY', 'GREETING', 'OVERLOOKED', 'ROW', 'IRS', 'MOMENTARY', 'IMPROBABLE', 'SUBMIT', 'THUNDERS', 'DEBARRED', 'FLORINS', 'FAINTED', 'FORWARD', 'INDUCED', 'FERVENTLY', 'PARAMOUNT', 'HOLLAND', 'DUTIES', 'REPRODUCE', 'UNADEPT', 'COW', 'DEBAR', 'EDUCATIONAL', 'THANKED', 'BLOODY', 'HOLDING', 'ER', 'DESERTION', 'FLASH', 'SCARCE', 'SWISS', 'WAFTED', 'DINNER', 'SWORE', 'VOYAGE', 'ABSTAINED', 'REDISTRIBUTION', 'ELDEST', 'PROFIT', 'SEEMINGLY', 'ARRANGE', 'ENSURE', 'ANNOUNCE', 'DECLINED', 'HERE', 'TESTIMONIES', 'UNEQUALLED', 'LAWLESS', 'FATIGUES', 'SWIMMING', 'UNCERTAIN', 'DIFFIDENCE', 'ADVANCE', 'COMPENSATE', 'SUBJECTS', 'FURNISHED', 'TARNISH', 'EXPRESSION', 'TRUEST', 'DIRT', 'STEERED', 'SORROWING', 'REPENTANT', 'BRIDE', 'JUNE', 'UTTERING', 'ASSIGNED', 'POPULAR', 'POURS', 'COMPREHEND', 'AGENT', 'UNCLE', 'THINK', 'STORE', 'SHADES', 'DISMAL', 'ENDEAVOURING', 'SHRINK', 'NOUGHT', 'RASHLY', 'NIGHTLY', 'DEMANDED', 'ACTUAL', 'FLITTED', 'RUNNING', 'LIVING', 'DISCLOSE ...

# %% [markdown]
# ## Part 3: Getting common words
#
# ### Overview
#
# Input: From this notebook, nothing.
#
# Output: We want a unique collection of common words to use in the next step to remove them from the text.
#
#
# ### Description
#
# Examine the code in the Part 0 section.  There is a file that contains common words located at the following URL:
#     http://www.cse.msu.edu/~ruppmatt/itm891/common_words.txt
#
# 1. Copy and paste the code from Part 0 to create a new string of common words.
# 2. Make a collection of the unique words from the string of common words.
#
# Note: Examine what that file contains.  Is it in the right format for what we need?  Is it upper or lowercase?  Examine the output of each step in the process for solving this step as you go along.

# %%
# Copy code from Part 0 here and extend it as described above
import urllib
url2 = 'http://www.cse.msu.edu/~ruppmatt/itm891/common_words.txt'
with urllib.request.urlopen(url2) as response:
    book_text2 = response.read().decode('utf-8')  # This is a string that contains the book
upper_book_text2 = book_text2.upper()
book_characters2 = set(book_text2)
chars_to_keep2 = set(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'))
replace_book_characters2 = book_characters2 - chars_to_keep2
for char in replace_book_characters2:
    upper_book_text2 = upper_book_text2.replace(char, ' ')
split_words2 = upper_book_text2.split()
my_set2 = set(split_words2)
print(my_set2)
# Out:
# {'EVEN', 'DEAD', 'HOLD', 'LIFT', 'SOIL', 'OFFER', 'DOWN', 'DOOR', 'NEW', 'THAT', 'NORTH', 'TERM', 'MAY', 'LIGHT', 'RAISE', 'CONSONANT', 'STRETCH', 'MOTION', 'CHECK', 'SCHOOL', 'STUDY', 'TAIL', 'DO', 'MINUS', 'WAR', 'INVENT', 'ANTI', 'CHARGE', 'BESIDES', 'CLOCK', 'PERSON', 'TOTAL', 'LIKE', 'TOWARD', 'FIELD', 'IS', 'TYPE', 'LEAST', 'FIVE', 'BOOK', 'DROP', 'POSE', 'BEAT', 'POWER', 'DEAR', 'MAJOR', 'PARTICULAR', 'DESPITE', 'BE', 'BIRD', 'FINISH', 'TOO', 'BETWEEN', 'STEEL', 'NOON', 'TUBE', 'EAST', 'SELECT', 'CAR', 'HELD', 'TINY', 'BUT', 'THOSE', 'ENTER', 'TEMPERATURE', 'ROSE', 'TAKE', 'WASH', 'LEVEL', 'SAFE', 'UPON', 'PROTECT', 'TRAIN', 'SIGN', 'LESS', 'INDICATE', 'REACH', 'CROWD', 'EGG', 'NOTHING', 'HUMAN', 'MARKET', 'EVERY', 'BUILD', 'MAIN', 'BENEATH', 'OTHER', 'PLAY', 'INCLUDE', 'REPLY', 'RICH', 'SOUND', 'SPELL', 'RULE', 'SUGGEST', 'TALK', 'THOUGHT', 'VIEW', 'NIGHT', 'MONTH', 'RAN', 'LIST', 'NEAR', 'FOUND', 'COMPARE', 'ICE', 'SENTENCE', 'SUCCESS', 'MOLECULE', 'WIFE', 'POEM', 'EXPECT', 'FATHER', 'OPEN', 'QUICK', 'TONE', 'CONNECT', 'ACT', 'TO', 'DESCRIBE', 'SEE', 'ONLY', 'SEND', 'CAMP', 'CITY', 'REAL', 'AS', 'DECIMAL', 'WAY', 'EXCEPT', 'WHOLE', 'WERE', 'DRY', 'MILK', 'EQUAL', 'GENTLE', 'MOUNTAIN', 'MINUTE', 'COAST', 'EVENING', 'DISCUSS', 'LITTLE', 'YOUNG', 'SAT', 'PROBLEM', 'MEN', 'LEARN', 'SEGMENT', 'THIS', 'THERE', 'HOUR', 'CHART', 'TOUCH', 'DON', 'FEAR', 'HAT', 'LED', 'SEAT', 'CELL', 'STEAD', 'FINGER', 'DEATH', 'PAY', 'PROVIDE', 'ROLL', 'LENGTH', 'WOMEN', 'MUCH', 'FARM', 'SCIENCE', 'BROKE', 'STEAM', 'BEHIND', 'PLANT', 'RACE', 'DEGREE', 'BEAR', 'REGARDING', 'BOAT', 'BONE', 'OVER', 'INSIDE', 'SHEET', 'COULD', 'SAY', 'BEYOND', 'BAT', 'SAIL', 'CONSIDER', 'AREA', 'NOUN', 'RIGHT', 'US', 'SISTER', 'OCCUR', 'PRODUCE', 'CAME', 'LAND', 'EYE', 'LIQUID', 'FOUR', 'MILLION', 'GUN', 'SUPPLY', 'DRINK', 'SAID', 'ANY', 'TRY', 'ART', 'HURRY', 'SUBTRACT', 'CONTAIN', 'NEIGHBOR', 'RUB', 'DIVISION', 'UP', 'DRESS', 'GIRL', 'WHERE', 'CENT', 'SEED', 'GLASS', 'A', 'SIZE', 'CLOUD', 'PLURAL', 'COURSE', 'DECIDE', 'WILD', 'CLASS', 'NOTICE', 'NAME', 'OCEAN', 'ANGER', 'DRAW', 'TRUCK', 'GROW', 'BACK', 'CARE', 'SON', 'SONG', 'RIDE', 'NINE', 'THEY', 'TABLE', 'PRESENT', 'CHANCE', 'COLUMN', 'ORGAN', 'SHELL', 'WISH', 'RIVER', 'TWO', 'TOWARDS', 'SCALE', 'SMALL', 'BIG', 'CIRCLE', 'HALF', 'SUFFIX', 'MORNING', 'TEST', 'CHARACTER', 'END', 'SPEAK', 'WEIGHT', 'REASON', 'SHIP', 'DICTIONARY', 'WORK', 'DOLLAR', 'WRONG', 'EXCLUDING', 'FLY', 'BY', 'YELLOW', 'CAUSE', 'PATH', 'SYMBOL', 'SHOW', 'DONE', 'FOLLOWING', 'BRANCH', 'EXAMPLE', 'ONE', 'NOW', 'LAY', 'CAPITAL', 'PORT', 'STRONG', 'BIT', 'WILL', 'QUESTION', 'MEAT', 'BASIC', 'CONCERNING', 'LONG', 'ENOUGH', 'FRONT', 'MOVE', 'MEASURE', 'FACT', 'WEATHER', 'SPECIAL', 'MISS', 'LIE', 'VIA', 'KIND', 'PAINT', 'DEAL', 'GATHER', 'SALT', 'MARK', 'WIDE', 'CONTROL', 'HORSE', 'SMILE', 'INTEREST', 'STATE', 'SEPARATE', 'FELT', 'WON', 'WHEN', 'GOT', 'BEEN', 'TOP', 'AFRAID', 'COAT', 'OUT', 'CHIEF', 'COUNTRY', 'VILLAGE', 'FEEL', 'HOLE', 'ABOARD', 'WALK', 'SO', 'ALSO', 'IT', 'NOT', 'QUITE', 'SWIM', 'GRAY', 'MINE', 'SHINE', 'YEAR', 'SEASON', 'MATCH', 'DREAM', 'WAS', 'YARD', 'HUNT', 'WATCH', 'SEARCH', 'USE', 'START', 'T', 'CHAIR', 'FIGHT', 'TIME', 'HER', 'MAP', 'THIRD', 'WHICH', 'CHORD', 'STATION', 'LOVE', 'SECTION', 'PEOPLE', 'MASTER', 'CREATE', 'TALL', 'WING', 'PATTERN', 'DAD', 'FALL', 'COME', 'GRASS', 'SELF', 'THIN', 'REQUIRE', 'SCORE', 'SUCH', 'HOPE', 'INSTANT', 'VERY', 'LARGE', 'BURN', 'TRADE', 'METHOD', 'FACE', 'ALWAYS', 'CONTINUE', 'SEEM', 'MEET', 'VERSUS', 'EXCITE', 'CORN', 'FRESH', 'HAS', 'HARD', 'OWN', 'POPULATE', 'POINT', 'NUMERAL', 'HEAVY', 'ATOM', 'WORD', 'VARY', 'WROTE', 'PLUS', 'CROSS', 'POUND', 'PROPER', 'SECOND', 'GREW', 'QUART', 'SURE', 'HOUSE', 'SET', 'STREAM', 'EARLY', 'HE', 'FREE', 'EQUATE', 'PROJECT', 'GREAT', 'SIDE', 'STOP', 'POSSIBLE', 'GRAND', 'GENERAL', 'WINDOW', 'POST', 'RATHER', 'SHAPE', 'COLONY', 'LOST', 'OPERATE', 'BEAUTY', 'I', 'GOOD', 'CLOTHE', 'CLIMB', 'LET', 'BROAD', 'MEANT', 'NOTE', 'LOOK', 'GREEN', 'CROP', 'CENTER ...

# %% [markdown]
# ## Part 4: Removing common words from the text
#
# ### Overview
#
# Input:
# * The collection of unique words in the text from Part 2
# * The collection of common words downloaded in Part 3
#
# Output: A collection of words in the book that aren't common
#
#
# ### Description
#
# Using the unique collection of words Part 2 (in the book) and Part 3 (common words overall) you should be able to remove the common words from the collection of unique words in the book.
#
# + If both of these are the same data type that represents a collection of unique objects, what operator would you use to get just the uncommon words in the book?

# %%
# Place your solution to the subproblem here
my_set3 = my_set - my_set2
print(my_set3)
# Out:
# {'WRAP', 'UNDERSTAND', 'COMPANION', 'INFORMED', 'RHONE', 'TEASED', 'PRECISION', 'DESTINY', 'THROUGHOUT', 'NURSED', 'ERADICATING', 'HORIZON', 'ENGAGES', 'ACCUSTOMED', 'OPERATION', 'NEITHER', 'HIDEOUSLY', 'GRASPING', 'SAVOURY', 'DIALOGUE', 'DISTORTED', 'WICKED', 'OVERLOOKING', 'WEAKENED', 'ROUSES', 'RETROSPECT', 'UNPERCEIVED', 'AMPHITHEATRE', 'PENETRATION', 'GEOGRAPHY', 'LAUDANUM', 'TEMPER', 'ETERNITY', 'WRETCHED', 'FIFTEEN', 'PERSONS', 'INURING', 'INJURER', 'CHEAT', 'COUNTRIES', 'WARMEST', 'APPROACHED', 'ROUGH', 'OPPOSING', 'REMIND', 'LINEN', 'VAINLY', 'REMOVES', 'ASIDE', 'DEC', 'IRRETRIEVABLE', 'IMMEDIATELY', 'OVERTHROW', 'HAST', 'ASSERTION', 'PROTECTORS', 'INQUIRING', 'LOOSE', 'KINDLED', 'RELIEVE', 'SOLITUDES', 'PRECIPITATE', 'BLIGHT', 'UNGUARDED', 'THINKS', 'CATASTROPHE', 'RETIREMENT', 'FREQUENT', 'ALOUD', 'DISEASE', 'POSITIVELY', 'POETS', 'YEARNED', 'ANIMATION', 'VERGE', 'ARIGHT', 'DISK', 'OPINIONS', 'EMULATE', 'INDICATING', 'SPARKLED', 'EMERGENCY', 'INDELIBLE', 'MECHANICS', 'QUANTITY', 'ELUDE', 'MOURNER', 'DENS', 'ANGRY', 'ILLNESS', 'DEATHBED', 'ADMIRE', 'LYCURGUS', 'SATIATED', 'HELPED', 'MET', 'THUNDERSTORM', 'CONTRADICTORY', 'PERMISSION', 'IMITATE', 'CLEARNESS', 'IDOL', 'ATTRIBUTED', 'FLOURISHING', 'MULTIFARIOUS', 'LONGED', 'REPAIRING', 'RELATION', 'SCENES', 'GUEST', 'NARRATION', 'FRIENDS', 'CONFIRMS', 'WAITING', 'LUKEWARM', 'TRANSMUTED', 'PREVAIL', 'FEARLESS', 'HOLDS', 'MODIFIED', 'SUSTAIN', 'BANISHED', 'INDIRECT', 'FALLING', 'CONTENTS', 'ACQUITTAL', 'JUDGED', 'INCOMMODED', 'ACTION', 'LIVED', 'SENSITIVE', 'SPURRED', 'COLONIZATION', 'FORBIDDEN', 'UNBRIDLED', 'RULED', 'HEAVING', 'EXTORT', 'FLIT', 'MAINLAND', 'MENACED', 'AMIABLE', 'MORTIFICATION', 'COVERED', 'WISEST', 'LIEU', 'GRATIFIED', 'DESIGNS', 'FULLY', 'LANTERN', 'PRIZED', 'SOOTHED', 'HASTE', 'EMBRACED', 'WATERFALLS', 'EXCOMMUNICATION', 'BUSINESS', 'BESTOW', 'VICTORIOUS', 'PRODUCED', 'PROMONTORY', 'SWORD', 'PETTICOAT', 'OCCASIONS', 'PULSE', 'RANKLING', 'CONSECRATED', 'STRIVING', 'COUNTLESS', 'GOING', 'PRECEDED', 'SIMPLER', 'ASCERTAIN', 'MORTAL', 'DECISION', 'RASH', 'CIVILISED', 'COMMANDED', 'GRUFF', 'KINGS', 'OBSCURED', 'NEWSLETTER', 'LEATHERN', 'YIELD', 'VARIED', 'WATCHED', 'SULLEN', 'PLEAD', 'PRONOUNCE', 'PEAKS', 'WONDERFUL', 'DRUG', 'NIECE', 'SERENE', 'FRIENDSHIP', 'STUMP', 'RECEIPT', 'CHARMING', 'STRUCK', 'ARMED', 'CONDUCE', 'MUTINY', 'SAILORS', 'AMERICAN', 'INNOCENCE', 'ENHANCED', 'ACTING', 'ENTREATING', 'MEANLY', 'INFLICT', 'INTERESTED', 'LESSON', 'IMPROVED', 'AMONGST', 'INSUPPORTABLE', 'TIDE', 'VOICES', 'PRINCIPLE', 'CONSISTENT', 'WESTMORLAND', 'BRED', 'DIFFERENCE', 'BECAME', 'SEIZE', 'OUTRAGES', 'REPORTS', 'LONDON', 'HEROIC', 'LAYING', 'BEGGED', 'DEBTS', 'HELPLESS', 'ANTIQUITY', 'CONSUMMATED', 'SPEAKS', 'OPPRESSION', 'PAYS', 'MANON', 'IDENTIFY', 'PUZZLED', 'SCOTLAND', 'DEPARTMENT', 'CABINETS', 'PILE', 'PROJECTS', 'PULLING', 'DISQUIET', 'SWALLOWED', 'RECENT', 'BLOODSHED', 'HIMSELF', 'WANDERINGS', 'CONTRIVED', 'ROMAN', 'COMRADES', 'ESCAPES', 'SYMPATHY', 'OTHERWISE', 'WEEP', 'COLLECTED', 'FLUCTUATING', 'VILLAINS', 'CONDUCTING', 'OWE', 'WHALE', 'WEALTH', 'STAGES', 'UNFOLDED', 'STORES', 'DORMANT', 'OVERFLOWING', 'ANNOYING', 'HEATH', 'AMIDST', 'CONVINCED', 'AVENUE', 'COMPREHENDED', 'INDEFATIGABLE', 'INCLUDES', 'THIRTEEN', 'CONSOLED', 'INFLICTION', 'COUNSEL', 'DOWNCAST', 'UNRAVEL', 'TENDERNESS', 'DETRACTS', 'ANDREW', 'SUPERFLUOUS', 'UNEXPECTED', 'HOLDER', 'SWITZERLAND', 'ENDOW', 'DENIED', 'BREACH', 'LOFTY', 'FLESH', 'KISS', 'PERSECUTED', 'THEE', 'QUIVERED', 'MEASURES', 'WAKEFIELD', 'OVERWHELMED', 'BADE', 'INCESSANTLY', 'CONGRATULATORY', 'SPOTS', 'JOURNEY', 'DESCRIPTION', 'ADDRESSED', 'SPREADING', 'GRADUALLY', 'PAIL', 'DRAWN', 'NORTHERLY', 'SATAN', 'RESCUED', 'COPYING', 'FASHIONED', 'NETWORK', 'SINCERITY', 'IMPATIENT', 'BUD', 'AFFABILITY', 'PROPAGATED', 'ASSURED', 'TEXTURE', 'COMES', 'ENOUNCED', 'EASILY', 'EXTREMES', 'RESIGNATION', 'POIGNANT', 'GRAVE', 'TREES', 'PRAYERS', 'LAMB', 'HAVOC', 'BOOKS', 'SUSPENSE', 'DEGRADATION', 'PGLAF', 'BID', 'YEARS', 'DEVOLVED', 'REPAI ...

# %% [markdown]
# ## Part 5: Getting the word frequency of uncommon words from the text
#
# ### Overview
#
# Input:
# * The cleaned book text from Part 1
# * The uncommon and unique words from Part 4
#
# Output:  A dictionary where the keys are the uncommon and unique words in the book and the value is the count of those words.  We also want small-length words removed.
#
# There are a number of things we need to consider:
# + We're going to begin again with the santized book text from Part 1.  We want a collection of words from that santized text, but this time a collection of all words, not just the unique words.
# + We have a unique collection of uncommon words in the book from Part 4.
# + Somehow we need to *iterate* over the list of uncommon words in the book and
#     - count the number of times those words appear
#     - store that count in a manner that associates them with the word
#     - ignore small-length words (we'll say less than 3 characters)
#     - since we need to iterate, we'll have to use a loop
# + Is there a way to count the number of times a word appears in a non-unique collection of words?  (Google it!)
# + We need a data structure to *map* a word to its count.
#     - is there a data structure that does a mapping from a key to a value?
#     - how do you associate a word (key) with its count (value)
#     - (this data structure might be mentioned in the output documentation above)
#
# Imagine that we had a list of words in a variable called `words_in_book` that contains a list of all words in the book.  If we wanted to iterate over it, we could:
#
#     for word in words_in_book:
#         if len(word) < 3:
#             continue
#         else:
#             pass # Here you would write the code to count the
#                  # number of tiem words would appear and store
#                  # it in a dictionary.  pass just means we don't
#                  # have any code yet for the else block

# %%
# Place your solution to the subproblem here
my_dict = dict()

for x in split_words:
    if len(x) < 3:
        continue
    else:
        if x in my_set and x in my_dict:
                my_dict[x] = my_dict[x] + 1
        else:
            my_dict[x] = 1
print(my_dict)
# Out:
# {'PROJECT': 87, 'GUTENBERG': 93, 'FRANKENSTEIN': 32, 'MARY': 4, 'WOLLSTONECRAFT': 4, 'GODWIN': 4, 'SHELLEY': 4, 'THIS': 449, 'EBOOK': 10, 'FOR': 524, 'THE': 4371, 'USE': 22, 'ANYONE': 9, 'ANYWHERE': 2, 'COST': 3, 'AND': 3046, 'WITH': 714, 'ALMOST': 40, 'RESTRICTIONS': 2, 'WHATSOEVER': 3, 'YOU': 644, 'MAY': 114, 'COPY': 12, 'GIVE': 24, 'AWAY': 53, 'UNDER': 32, 'TERMS': 29, 'LICENSE': 16, 'INCLUDED': 4, 'ONLINE': 4, 'WWW': 6, 'NET': 5, 'TITLE': 2, 'MODERN': 12, 'PROMETHEUS': 2, 'AUTHOR': 6, 'RELEASE': 3, 'DATE': 6, 'JUNE': 2, 'LAST': 34, 'UPDATED': 2, 'JANUARY': 1, 'LANGUAGE': 20, 'ENGLISH': 9, 'CHARACTER': 8, 'SET': 21, 'ENCODING': 1, 'UTF': 1, 'START': 3, 'PRODUCED': 15, 'JUDITH': 2, 'BOSS': 2, 'CHRISTY': 2, 'PHILLIPS': 2, 'LYNN': 2, 'HANNINEN': 2, 'DAVID': 2, 'MELTZER': 2, 'HTML': 2, 'VERSION': 3, 'HAINES': 2, 'FURTHER': 4, 'CORRECTIONS': 2, 'MENNO': 2, 'LEEUW': 2, 'CONTENTS': 2, 'LETTER': 33, 'CHAPTER': 48, 'MRS': 4, 'SAVILLE': 4, 'ENGLAND': 21, 'PETERSBURGH': 3, 'DEC': 1, 'WILL': 201, 'REJOICE': 1, 'HEAR': 20, 'THAT': 1033, 'DISASTER': 4, 'HAS': 66, 'ACCOMPANIED': 9, 'COMMENCEMENT': 5, 'ENTERPRISE': 10, 'WHICH': 565, 'HAVE': 370, 'REGARDED': 6, 'SUCH': 93, 'EVIL': 23, 'FOREBODINGS': 2, 'ARRIVED': 29, 'HERE': 35, 'YESTERDAY': 4, 'FIRST': 108, 'TASK': 19, 'ASSURE': 5, 'DEAR': 72, 'SISTER': 28, 'WELFARE': 2, 'INCREASING': 2, 'CONFIDENCE': 4, 'SUCCESS': 12, 'UNDERTAKING': 13, 'ALREADY': 33, 'FAR': 39, 'NORTH': 13, 'LONDON': 8, 'WALK': 6, 'STREETS': 6, 'FEEL': 50, 'COLD': 31, 'NORTHERN': 6, 'BREEZE': 10, 'PLAY': 7, 'UPON': 128, 'CHEEKS': 7, 'BRACES': 1, 'NERVES': 3, 'FILLS': 5, 'DELIGHT': 32, 'UNDERSTAND': 17, 'FEELING': 27, 'TRAVELLED': 6, 'FROM': 400, 'REGIONS': 6, 'TOWARDS': 94, 'ADVANCING': 4, 'GIVES': 6, 'FORETASTE': 1, 'THOSE': 92, 'ICY': 3, 'CLIMES': 1, 'INSPIRITED': 3, 'WIND': 27, 'PROMISE': 22, 'DAYDREAMS': 2, 'BECOME': 33, 'MORE': 166, 'FERVENT': 2, 'VIVID': 3, 'TRY': 4, 'VAIN': 13, 'PERSUADED': 7, 'POLE': 4, 'SEAT': 5, 'FROST': 5, 'DESOLATION': 6, 'EVER': 85, 'PRESENTS': 3, 'ITSELF': 22, 'IMAGINATION': 23, 'REGION': 4, 'BEAUTY': 27, 'THERE': 83, 'MARGARET': 10, 'SUN': 45, 'VISIBLE': 6, 'ITS': 129, 'BROAD': 2, 'DISK': 3, 'JUST': 19, 'SKIRTING': 1, 'HORIZON': 6, 'DIFFUSING': 1, 'PERPETUAL': 5, 'SPLENDOUR': 1, 'YOUR': 261, 'LEAVE': 22, 'PUT': 15, 'SOME': 148, 'TRUST': 6, 'PRECEDING': 6, 'NAVIGATORS': 3, 'SNOW': 16, 'ARE': 195, 'BANISHED': 5, 'SAILING': 1, 'OVER': 58, 'CALM': 20, 'SEA': 34, 'WAFTED': 4, 'LAND': 20, 'SURPASSING': 2, 'WONDERS': 5, 'EVERY': 109, 'HITHERTO': 12, 'DISCOVERED': 35, 'HABITABLE': 1, 'GLOBE': 2, 'PRODUCTIONS': 2, 'FEATURES': 7, 'WITHOUT': 38, 'EXAMPLE': 2, 'PHENOMENA': 2, 'HEAVENLY': 4, 'BODIES': 3, 'UNDOUBTEDLY': 1, 'UNDISCOVERED': 2, 'SOLITUDES': 1, 'WHAT': 133, 'NOT': 531, 'EXPECTED': 12, 'COUNTRY': 56, 'ETERNAL': 11, 'LIGHT': 42, 'DISCOVER': 17, 'WONDROUS': 7, 'POWER': 39, 'ATTRACTS': 1, 'NEEDLE': 1, 'REGULATE': 2, 'THOUSAND': 27, 'CELESTIAL': 5, 'OBSERVATIONS': 1, 'REQUIRE': 2, 'ONLY': 125, 'VOYAGE': 15, 'RENDER': 10, 'THEIR': 186, 'SEEMING': 2, 'ECCENTRICITIES': 1, 'CONSISTENT': 1, 'SHALL': 107, 'SATIATE': 1, 'ARDENT': 10, 'CURIOSITY': 14, 'SIGHT': 25, 'PART': 43, 'WORLD': 45, 'NEVER': 69, 'BEFORE': 148, 'VISITED': 17, 'TREAD': 3, 'IMPRINTED': 2, 'FOOT': 5, 'MAN': 137, 'THESE': 157, 'ENTICEMENTS': 2, 'THEY': 213, 'SUFFICIENT': 20, 'CONQUER': 1, 'ALL': 218, 'FEAR': 40, 'DANGER': 12, 'DEATH': 79, 'INDUCE': 4, 'COMMENCE': 13, 'LABORIOUS': 3, 'JOY': 42, 'CHILD': 35, 'FEELS': 2, 'WHEN': 329, 'EMBARKS': 1, 'LITTLE': 58, 'BOAT': 17, 'HIS': 535, 'HOLIDAY': 1, 'MATES': 1, 'EXPEDITION': 4, 'DISCOVERY': 18, 'NATIVE': 28, 'RIVER': 12, 'BUT': 692, 'SUPPOSING': 2, 'CONJECTURES': 1, 'FALSE': 5, 'CANNOT': 50, 'CONTEST': 1, 'INESTIMABLE': 1, 'BENEFIT': 7, 'CONFER': 1, 'MANKIND': 11, 'GENERATION': 2, 'DISCOVERING': 3, 'PASSAGE': 9, 'NEAR': 39, 'COUNTRIES': 4, 'REACH': 5, 'PRESENT': 30, 'MANY': 70, 'MONTHS': 39, 'REQUISITE': 1, 'ASCERTAINING': 1, 'SECRET': 13, 'MAGNET': 1, 'POSSIBLE': 11, 'CAN': 103, 'EFFECTED ...

# %% [markdown]
# ## Part 6: Generating the word cloud
#
# ### Overview
#
# Input: the dictionary of word and frequency key, value pairs.
#
# Output: the word cloud graphic
#
#
# ### Description
#
# At this point we're going to let a third-party handle rendering this graphic.  The only thing in the code below you need to change is the variable `CHANGE_ME` to be the dictionary output of Part 5.

# %%
wordcloud = WordCloud(width=1024,\
                      height=768,\
                      relative_scaling=0.5,\
                      normalize_plurals=True).generate_from_frequencies(my_dict)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
